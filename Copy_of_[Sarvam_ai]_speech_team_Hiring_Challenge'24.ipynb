# %% [markdown]
# <a href="https://colab.research.google.com/github/poornima79/Maternity-clothing-site/blob/main/Copy_of_%5BSarvam_ai%5D_speech_team_Hiring_Challenge'24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🚀 **Join Our Speech Team at Sarvam AI!** 🚀
#
#
#
# We at [Sarvam AI](https://www.sarvam.ai/) are on a mission to revolutionize the GenAI landscape in India, and we're looking for talented **Data Engineers** and **ML Engineers** to help us achieve this. Become part of a team dedicated to building state-of-the-art ML systems for Speech Recognition and Text-to-Speech applications in Indian languages.
#
#
#
# **Why Join Our Speech Team?**
#
# - 🧠 **Develop Cutting-Edge ML Models:** Work on the forefront of machine learning to develop systems that understand and speak multiple Indian languages.
#
# - 📊 **Handle Large-Scale Data Sets:** Dive into dataset curation, managing and processing over 1M hours of audio data to train our models.
#
# - 💻 **Advanced GPU Infrastructure:** Get hands-on experience with our massive A100 and H100 GPU cluster, pushing the boundaries of what AI can achieve.
#
# - 🛠️ **Solve Real-World Problems:** Tackle hard applied research and engineering challenges with a direct impact on our products.
#
# - 🌐 **Work with Top Talent:** Collaborate with some of India's best ML Engineers and Product Developers in an environment that values innovation and creativity.
#
#
#
# **We're Excited to Offer the Following Opportunities (Full Time only):**
#
# - 🌱 **Summer Internship (2 months on-site/remote, earning up to 50k per month):** Ideal for freshers or students with a foundational grasp of ML and programming.
#
#   - **Data Engineer:** Engage in web scraping, manage distributed data processing, and develop robust data pipelines.
#
#   - **ML Engineer:** Train, monitor and eval state-of-the-art speech models.
#
#
#
# - 🔥 **AI Residency (6 months on-site, earning up to 1L per month):** Perfect for those with professional experience or significant expertise. Contribute to our groundbreaking projects and refine your skills.
#
#   - **Data Engineer:** Oversee large-scale data mining and sophisticated engineering tasks for massive data flows.
#
#   - **ML Engineer:** Train advanced speech models on powerful GPU clusters using frameworks like PyTorch and JAX, and tools like NeMo and HuggingFace Transformers.
#
#
#
# **About Sarvam AI:**
#
# Sarvam AI is a well-funded GenAI startup focused on creating full-stack GenAI systems and applications tailored for India. Based out of Bangalore and Chennai, Sarvam AI is a place for those who are passionate about driving significant advancements through Generative AI, have a love for Indian languages, and are eager to make a substantial impact.
#
#
#
# **Join Us!**
#
# Complete our [Hiring Challenge in the Colab Notebook](https://colab.research.google.com/drive/1EiiLTf5zB8Jm2PxdU3H20rWUr40FrsGM?usp=sharing) to showcase your skills! After completing the challenge, please apply through this [Google Form](https://forms.gle/yP4Vd9QhiETTqEtW8). We’re eager to see your innovative solutions and potentially welcome you aboard to help shape the future of AI in India.
#
#
#
# *Note: Admissions are on a rolling basis until all positions are filled. Apply early to secure your spot in our team!*
#
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 🌟 Welcome to the Speech Team Hiring Challenge! 🚀
#
# Hey there! We're thrilled to kick off this exciting challenge with two awesome tasks tailored to test your prowess in speech and text data analysis. These tasks are crucial for our hiring process and mirror the real-world scenarios our team loves to tackle. 🎯
#
# **Task 1: Semantic Chunking of a YouTube Video** 📹
# - Dive into extracting meaningful audio-text pairs from a specific video. Show us your skill in achieving precise segmentation and alignment!
#
# **Task 2: Exploratory Data Analysis of New Testament Audio and Text** 📖
# - Get your hands dirty with a deep dive into the audio and text from the New Testament in your mother tongue. We're looking for sharp insights that could revolutionize text-to-speech and speech-to-text technologies.
#
# Please tackle both tasks with your full creativity and analytical skills as they are equally important in our evaluation. 🤓 🏋️‍♂️ Your innovative approaches, depth of analysis, and tech-savviness will be key to understanding how well you fit into our dynamic team.
#
# **Submission Instructions:**
# - Make sure to create a copy of your Google Colab notebook for each task.
# - Set the notebook to **shareable** and grant viewing access to **abhigyan@sarvam.ai**.
# - Once you've perfected your work, please paste the link to your notebook in the [Google Form provided](https://forms.gle/qxy2LF4Jtph7xhYHA). This step is crucial for us to review your submissions properly.
#
# Good luck, and let's see what amazing things you can uncover! 🌈👀
#
#
#
# ---

# %% [markdown]
# ## Task 1: Semantic Chunking of a Youtube Video
#
# **Problem Statement:**
#
# The objective is to extract high-quality, meaningful (semantic) segments from the specified YouTube video: [Watch Video](https://www.youtube.com/watch?v=Sby1uJ_NFIY).
#
# Suggested workflow:
# 1. **Download Video and Extract Audio:** Download the video and separate the audio component.
# 2. **Transcription of Audio:** Utilize an open-source Speech-to-Text model to transcribe the audio. *Provide an explanation of the chosen model and any techniques used to enhance the quality of the transcription.*
# 3. **Time-Align Transcript with Audio:** *Describe the methodology and steps for aligning the transcript with the audio.*
# 4. **Semantic Chunking of Data:** Slice the data into audio-text pairs, using both semantic information from the text and voice activity information from the audio, with each audio-chunk being less than 15s in length. *Explain the logic used for semantic chunking and discuss the strengths and weaknesses of your approach.*
#
# **Judgement Criteria:**
#
# 1. **Precision-Oriented Evaluation:** The evaluation focuses on precision rather than recall. Higher scores are achieved by reporting fewer but more accurate segments rather than a larger number of segments with inaccuracies. Segment accuracy is determined by:
#    - **Transcription Quality:** Accuracy of the text transcription for each audio chunk.
#    - **Segment Quality:** Semantic richness of the text segments.
#    - **Timestamp Accuracy:** Precision of the start and end times for each segment. Avoid audio cuts at the start or end of a segment.
#
# 2. **Detailed Explanations:** Provide reasoning behind each step in the process.
# 3. **Generalization:** Discuss the general applicability of your approach, potential failure modes on different types of videos, and adaptation strategies for other languages.
# 4. **[Bonus-1]** **Gradio-app Interface:** Wrap your code in a gradio-app which takes in youtube link as input and displays the output in a text-box.
# 5. **[Bonus-2]** **Utilizing Ground-Truth Transcripts:** Propose a method to improve the quality of your transcript using a ground-truth transcript provided as a single text string. Explain your hypothesis for this approach. *Note that code-snippet isn't required for this question.*
#
#   As an example - for the audio extracted from [yt-link](https://www.youtube.com/watch?v=ysLiABvVos8), how can we leverage transcript scraped from [here](https://www.newsonair.gov.in/bulletins-detail/english-morning-news-7/), to improve the overall transcription quality of segments?
#
# **Submission Format:**
#
# Your submission should be a well-documented Jupyter notebook capable of reproducing your results. The notebook should automatically install all required dependencies and output the results in the specified format.
#
# - **Output Format:** Provide the results as a list of dictionaries, each representing a semantic chunk. Each dictionary should include:
#   - `chunk_id`: A unique identifier for the chunk (integer).
#   - `chunk_length`: The duration of the chunk in seconds (float).
#   - `text`: The transcribed text of the chunk (string).
#   - `start_time`: The start time of the chunk within the video (float).
#   - `end_time`: The end time of the chunk within the video (float).
#
# ```python
# sample_output_list = [
#     {
#         "chunk_id": 1,
#         "chunk_length": 14.5,
#         "text": "Here is an example of a semantic chunk from the video.",
#         "start_time": 0.0,
#         "end_time": 14.5,
#     },
#     # Additional chunks follow...
# ]
# ```
#
# Ensure that your code is clear, well-commented, and easy to follow, with explanations for each major step and decision in the process. The notebook should be able to install all the dependencies automatically and generate the reported output when run.
#
#
# ---

# %%
# Your code for Task 1 goes here!
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='whisper.transcribe')

# !pip uninstall -y whisper
# !pip install pytube
# !pip install openai-whisper
# !pip install pytube moviepy nltk gradio

from pytube import YouTube
from moviepy.editor import VideoFileClip
import os
import whisper
from nltk.tokenize import sent_tokenize
import nltk
import json

# Ensure the required NLTK data files are downloaded
nltk.download('punkt')

def download_youtube_video(url, output_path='video.mp4'):
    yt = YouTube(url)
    stream = yt.streams.filter(only_audio=False).first()
    stream.download(filename=output_path)
    return output_path

def extract_audio(video_path, audio_path='audio.wav'):
    video = VideoFileClip(video_path)
    video.audio.write_audiofile(audio_path)
    return audio_path

video_url = 'https://www.youtube.com/watch?v=Sby1uJ_NFIY&list=PPSV'
video_path = download_youtube_video(video_url)
audio_path = extract_audio(video_path)

def transcribe_audio(audio_path):
    model = whisper.load_model("base")
    result = model.transcribe(audio_path)
    return result['segments']

segments = transcribe_audio(audio_path)

def semantic_chunking(segments, max_length=15.0):
    chunks = []
    current_chunk = {
        "chunk_id": 1,
        "chunk_length": 0,
        "text": "",
        "start_time": 0,
        "end_time": 0
    }
    for segment in segments:
        text = segment['text']
        sentences = sent_tokenize(text)
        for sentence in sentences:
            sentence_length = segment['end'] - segment['start']
            if current_chunk['chunk_length'] + sentence_length <= max_length:
                current_chunk['text'] += " " + sentence
                current_chunk['end_time'] = segment['end']
                current_chunk['chunk_length'] += sentence_length
            else:
                chunks.append(current_chunk)
                current_chunk = {
                    "chunk_id": current_chunk['chunk_id'] + 1,
                    "chunk_length": sentence_length,
                    "text": sentence,
                    "start_time": segment['start'],
                    "end_time": segment['end']
                }
    if current_chunk['text']:
        chunks.append(current_chunk)
    return chunks

semantic_chunks = semantic_chunking(segments)

# Example output
print(json.dumps(semantic_chunks, indent=4))
# Out:
# WARNING: Skipping whisper as it is not installed.
# Requirement already satisfied: pytube in /usr/local/lib/python3.10/dist-packages (15.0.0)
# Requirement already satisfied: openai-whisper in /usr/local/lib/python3.10/dist-packages (20231117)
# Requirement already satisfied: triton<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (2.2.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (0.58.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (1.25.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (2.2.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (4.66.4)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (10.1.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton<3,>=2.0.0->openai-whisper) (3.14.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper) (0.41.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper) (2023.12.25)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper) (2.31.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->openai-whisper) (12.4.127)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper) (1.3.0)
# Requirement already satisfied: pytube in /usr/local/lib/python3.10/dist-packages (15.0.0)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (1.0.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: gradio in /usr/local/lib/python3.10/dist-packages (4.31.2)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.66.4)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from moviepy) (1.25.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.31.6)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.4.9)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.2.2)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (from gradio) (0.111.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio) (0.3.2)
# Requirement already satisfied: gradio-client==0.16.3 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.16.3)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.20.3)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.10.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio) (24.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.0.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (9.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.7.1)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.4.4)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.11.0)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.0.7)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.29.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.16.3->gradio) (2023.6.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.16.3->gradio) (11.0.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (0.12.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio) (3.14.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg>=0.2.0->moviepy) (67.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio) (0.0.3)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio) (5.10.0)
# Requirement already satisfied: email_validator>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio) (2.1.1)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email_validator>=2.0.0->fastapi->gradio) (2.6.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.16.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.24.1->gradio) (1.2.1)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio) (0.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# MoviePy - Writing audio in audio.wav
# MoviePy - Done.
# [
#     {
#         "chunk_id": 1,
#         "chunk_length": 12.08,
#         "text": "  Congratulations to you Mr. Raghavan for that. Thank you so much for joining us.  Over to you.  Hi everybody. How are you?",
#         "start_time": 0,
#         "end_time": 10.0
#     },
#     {
#         "chunk_id": 2,
#         "chunk_length": 12.639999999999997,
#         "text": " Okay I am not hearing this at all. It's like a post lunch energy downer or something.  Let's hear it.",
#         "start_time": 11.76,
#         "end_time": 20.48
#     },
#     {
#         "chunk_id": 3,
#         "chunk_length": 11.279999999999998,
#         "text": "Are you guys awake?  All right you better be because we have a superstar guest here.  You heard the 41 million dollars and I didn't hear honestly anything she said after that.",
#         "start_time": 18.080000000000002,
#         "end_time": 31.52
#     },
#     {
#         "chunk_id": 4,
#         "chunk_length": 10.079999999999998,
#         "text": " So we're going to ask for about 40 million dollars from him by the end of this conversation.  But let's get started.",
#         "start_time": 33.120000000000005,
#         "end_time": 44.88
#     },
#     {
#         "chunk_id": 5,
#         "chunk_length": 11.920000000000009,
#         "text": "I want to introduce Vivek and Pratius, she's co-founder who's not here.  We wanted to start with a playing a video of what OpenHathe does.",
#         "start_time": 39.68,
#         "end_time": 52.400000000000006
#     },
#     {
#         "chunk_id": 6,
#         "chunk_length": 12.800000000000004,
#         "text": "I encourage all of you to go  to the website, www.severalm.ai and check it out.",
#         "start_time": 45.68,
#         "end_time": 59.199999999999996
#     },
#     {
#         "chunk_id": 7,
#         "chunk_length": 12.159999999999997,
#         "text": "But let me start by introducing Vivek. Vivek is a",
#         "start_time": 53.12,
#         "end_time": 59.199999999999996
#     },
#     {
#         "chunk_id": 8,
#         "chunk_length": 12.320000000000007,
#         "text": " dear friend and he is very, very modest. One of the most modest guys that I know.",
#         "start_time": 59.199999999999996,
#         "end_time": 65.36
#     },
#     {
#         "chunk_id": 9,
#         "chunk_length": 12.480000000000011,
#         "text": "But his personal  journey Vivek, you've got a PhD from Carnegie Mellon.",
#         "start_time": 59.199999999999996,
#         "end_time": 71.68
#     },
#     {
#         "chunk_id": 10,
#         "chunk_length": 11.76000000000002,
#         "text": "You've sat in and sold the company to Magma.  Vivek and I moved back to India from both in the valley on the same day actually.",
#         "start_time": 65.36,
#         "end_time": 77.68
#     },
#     {
#         "chunk_id": 11,
#         "chunk_length": 12.16000000000001,
#         "text": "And you've been  in India for the last 16 years.",
#         "start_time": 72.24,
#         "end_time": 84.4
#     },
#     {
#         "chunk_id": 12,
#         "chunk_length": 6.719999999999999,
#         "text": "And what most people don't know is your journey at Adhar.",
#         "start_time": 77.68,
#         "end_time": 84.4
#     },
#     {
#         "chunk_id": 13,
#         "chunk_length": 8.560000000000002,
#         "text": " He spent 13 years selflessly at Adhar.",
#         "start_time": 85.12,
#         "end_time": 93.68
#     },
#     {
#         "chunk_id": 14,
#         "chunk_length": 8.560000000000002,
#         "text": "Nobody would have heard of him.",
#         "start_time": 85.12,
#         "end_time": 93.68
#     },
#     {
#         "chunk_id": 15,
#         "chunk_length": 14.960000000000008,
#         "text": "But he was a pioneering  technology visionary behind Adhar which we all take for granted today.",
#         "start_time": 85.12,
#         "end_time": 100.08000000000001
#     },
#     {
#         "chunk_id": 16,
#         "chunk_length": 10.720000000000013,
#         "text": "So please give it out.  Honestly when people, when I think of selfless service, truly selfless service, I always think of",
#         "start_time": 93.68,
#         "end_time": 106.64000000000001
#     },
#     {
#         "chunk_id": 17,
#         "chunk_length": 14.400000000000006,
#         "text": " Vivek. And since then he also was at AI for Bharat which we're going to touch on where he met Pratiush's",
#         "start_time": 106.64,
#         "end_time": 113.84
#     },
#     {
#         "chunk_id": 18,
#         "chunk_length": 13.759999999999991,
#         "text": " other co-founder. Pratiush had a PhD from ETH at Zurich.",
#         "start_time": 113.84,
#         "end_time": 120.72
#     },
#     {
#         "chunk_id": 19,
#         "chunk_length": 13.759999999999991,
#         "text": "He was in the IBM research. He was at",
#         "start_time": 113.84,
#         "end_time": 120.72
#     },
#     {
#         "chunk_id": 20,
#         "chunk_length": 12.800000000000011,
#         "text": " Microsoft Research playing a key role and a faculty at IIT Madras and at AI for Bharat. So that's",
#         "start_time": 120.72,
#         "end_time": 127.12
#     },
#     {
#         "chunk_id": 21,
#         "chunk_length": 10.71999999999997,
#         "text": " a little brief introduction about them. These guys are modest, modest engineers.",
#         "start_time": 127.12,
#         "end_time": 132.48
#     },
#     {
#         "chunk_id": 22,
#         "chunk_length": 11.519999999999982,
#         "text": "So they don't  do their own hon.",
#         "start_time": 127.12,
#         "end_time": 138.64
#     },
#     {
#         "chunk_id": 23,
#         "chunk_length": 12.319999999999993,
#         "text": "So forgive me for tooting their hon in this case. But let's jump right in",
#         "start_time": 132.48,
#         "end_time": 138.64
#     },
#     {
#         "chunk_id": 24,
#         "chunk_length": 12.480000000000018,
#         "text": " about the money. Funding.",
#         "start_time": 140.48,
#         "end_time": 146.72
#     },
#     {
#         "chunk_id": 25,
#         "chunk_length": 12.480000000000018,
#         "text": "41 million bucks man. That's a lot of money.",
#         "start_time": 140.48,
#         "end_time": 146.72
#     },
#     {
#         "chunk_id": 26,
#         "chunk_length": 11.039999999999992,
#         "text": "Every entrepreneur here is  saying what the hell did guys do?",
#         "start_time": 140.48,
#         "end_time": 151.51999999999998
#     },
#     {
#         "chunk_id": 27,
#         "chunk_length": 12.079999999999956,
#         "text": "What did the investors see to write such a big check?  No, I think it's a trend of what's going on in India.",
#         "start_time": 146.72,
#         "end_time": 159.83999999999997
#     },
#     {
#         "chunk_id": 28,
#         "chunk_length": 13.19999999999996,
#         "text": "I think that for the very first time,  I think the investors have looked at, let's try and build something deep-tech out of the country.",
#         "start_time": 152.56,
#         "end_time": 166.32
#     },
#     {
#         "chunk_id": 29,
#         "chunk_length": 14.0,
#         "text": " And let's try to figure out how to build something as a foundational technology out of the country.  And that's really what's really exciting.",
#         "start_time": 166.32,
#         "end_time": 180.32
#     },
#     {
#         "chunk_id": 30,
#         "chunk_length": 9.439999999999998,
#         "text": "And I think that about, as Balav was mentioning for",
#         "start_time": 170.88,
#         "end_time": 180.32
#     },
#     {
#         "chunk_id": 31,
#         "chunk_length": 12.480000000000018,
#         "text": " the past 15 years, I've been working in both digital public infrastructure and kind of  non-profit kind of things.",
#         "start_time": 180.32,
#         "end_time": 193.6
#     },
#     {
#         "chunk_id": 32,
#         "chunk_length": 10.0,
#         "text": "But when this whole thing of generative AI came about,  we said, okay, how can I actually make a difference in this space?",
#         "start_time": 189.28,
#         "end_time": 200.88
#     },
#     {
#         "chunk_id": 33,
#         "chunk_length": 12.719999999999999,
#         "text": "And I said, maybe this is the  opportunity to actually come out and really build something.",
#         "start_time": 195.2,
#         "end_time": 207.92
#     },
#     {
#         "chunk_id": 34,
#         "chunk_length": 14.0,
#         "text": "And the only way that we realize that  you can do it is actually in the private sector.",
#         "start_time": 200.88,
#         "end_time": 214.88
#     },
#     {
#         "chunk_id": 35,
#         "chunk_length": 11.04000000000002,
#         "text": "And I think that's, and then when we went out  there and we said, we want to build something, which is a continuation.",
#         "start_time": 207.92,
#         "end_time": 219.12
#     },
#     {
#         "chunk_id": 36,
#         "chunk_length": 9.52000000000001,
#         "text": "And fundamentally,  the question is the reason of what we want to do at Server May I is we want to basically make",
#         "start_time": 215.04,
#         "end_time": 224.56
#     },
#     {
#         "chunk_id": 37,
#         "chunk_length": 13.599999999999966,
#         "text": " generative AI available and accessible to the people in the country. And that's the intent.",
#         "start_time": 224.56,
#         "end_time": 231.35999999999999
#     },
#     {
#         "chunk_id": 38,
#         "chunk_length": 11.04000000000002,
#         "text": " And when we said that we want to do this, there was a resonance in the investment community.  And I think it's a responsibility to really to show that something like this can be built out of",
#         "start_time": 231.35999999999999,
#         "end_time": 242.4
#     },
#     {
#         "chunk_id": 39,
#         "chunk_length": 12.800000000000011,
#         "text": " India. So we see that as as as as confidence and a responsibility.",
#         "start_time": 242.4,
#         "end_time": 248.8
#     },
#     {
#         "chunk_id": 40,
#         "chunk_length": 11.039999999999992,
#         "text": "And I also hope it's a trend  that that you know that there are many more people like like us who are backed.",
#         "start_time": 242.4,
#         "end_time": 253.44
#     },
#     {
#         "chunk_id": 41,
#         "chunk_length": 11.04000000000002,
#         "text": "Because if you look  at it, maybe it's a large number in a you know in the Indian context, but in the global context,",
#         "start_time": 248.8,
#         "end_time": 259.84000000000003
#     },
#     {
#         "chunk_id": 42,
#         "chunk_length": 13.840000000000032,
#         "text": " I think there is just there should be many, many more entrepreneurs who are back to do things in  India. I'm going to come back to the many more entrepreneurs.",
#         "start_time": 259.84000000000003,
#         "end_time": 269.04
#     },
#     {
#         "chunk_id": 43,
#         "chunk_length": 11.440000000000055,
#         "text": "I'm obviously going to ask you about  Bhavish's Krutram.",
#         "start_time": 264.4,
#         "end_time": 276.40000000000003
#     },
#     {
#         "chunk_id": 44,
#         "chunk_length": 13.600000000000023,
#         "text": "So we're going to come back to that question. But again, 41 million dollars.",
#         "start_time": 269.6,
#         "end_time": 276.40000000000003
#     },
#     {
#         "chunk_id": 45,
#         "chunk_length": 9.920000000000016,
#         "text": " I mean, all of what you said, you know, two million dollars, you know, that's a good no-one of money  for a startup which you know, which has not yet built anything.",
#         "start_time": 276.40000000000003,
#         "end_time": 286.32000000000005
#     },
#     {
#         "chunk_id": 46,
#         "chunk_length": 11.840000000000146,
#         "text": "What are you going to do with all this money?  I can call the problem. I can have a perfect solution for the problem.",
#         "start_time": 280.88,
#         "end_time": 292.08000000000004
#     },
#     {
#         "chunk_id": 47,
#         "chunk_length": 14.079999999999984,
#         "text": " I think in the last week I've got lots of calls, lots of people telling me how I can do.  No, but I know you first. I'll be landed in the country the same day.",
#         "start_time": 292.08000000000004,
#         "end_time": 301.84
#     },
#     {
#         "chunk_id": 48,
#         "chunk_length": 10.95999999999998,
#         "text": "I'm in the front of the queue.  No, but but but honestly, I think the key thing in this is is to putting together an amazing team.",
#         "start_time": 297.52,
#         "end_time": 309.52
#     },
#     {
#         "chunk_id": 49,
#         "chunk_length": 10.399999999999977,
#         "text": " And we actually have an amazing team, but we believe that it is talent that will drive this kind of  thing.",
#         "start_time": 309.52,
#         "end_time": 319.91999999999996
#     },
#     {
#         "chunk_id": 50,
#         "chunk_length": 10.079999999999927,
#         "text": "And so it is it is to get get key talent. And of course, the other thing is compute.",
#         "start_time": 314.88,
#         "end_time": 319.91999999999996
#     },
#     {
#         "chunk_id": 51,
#         "chunk_length": 11.279999999999973,
#         "text": "This is  extremely expensive compute wise to actually do these kinds of things.",
#         "start_time": 314.88,
#         "end_time": 326.88
#     },
#     {
#         "chunk_id": 52,
#         "chunk_length": 13.680000000000007,
#         "text": "And I think that those are the  two primary things that that you know, we'd use this for.",
#         "start_time": 320.64,
#         "end_time": 334.32
#     },
#     {
#         "chunk_id": 53,
#         "chunk_length": 14.879999999999995,
#         "text": "Okay. I'm computing in my own head as an",
#         "start_time": 326.88,
#         "end_time": 334.32
#     },
#     {
#         "chunk_id": 54,
#         "chunk_length": 14.400000000000034,
#         "text": " entrepreneur talent. Okay, you have like 2015 people. How much are you paying these guys?",
#         "start_time": 334.32,
#         "end_time": 339.12
#     },
#     {
#         "chunk_id": 55,
#         "chunk_length": 10.079999999999984,
#         "text": "But okay,  well, you won't touch on that.",
#         "start_time": 334.32,
#         "end_time": 344.4
#     },
#     {
#         "chunk_id": 56,
#         "chunk_length": 14.479999999999961,
#         "text": "But let's talk about what you guys actually built. What is what is  open Hathi?",
#         "start_time": 339.12,
#         "end_time": 348.32
#     },
#     {
#         "chunk_id": 57,
#         "chunk_length": 10.560000000000002,
#         "text": "Well, how would you explain open Hathi to many people here who might not have no  about it?",
#         "start_time": 344.4,
#         "end_time": 354.96
#     },
#     {
#         "chunk_id": 58,
#         "chunk_length": 13.279999999999973,
#         "text": "So I think open Hathi is so, so first of all, right? We come from I personally come from",
#         "start_time": 348.32,
#         "end_time": 354.96
#     },
#     {
#         "chunk_id": 59,
#         "chunk_length": 13.919999999999959,
#         "text": " the open source ecosystem and we we and also from the DPI ecosystem. So we believe that for this",
#         "start_time": 354.96,
#         "end_time": 361.91999999999996
#     },
#     {
#         "chunk_id": 60,
#         "chunk_length": 11.840000000000032,
#         "text": " to work, we need the ecosystem to be successful. And as a result of that, one of the first things we",
#         "start_time": 361.91999999999996,
#         "end_time": 367.84
#     },
#     {
#         "chunk_id": 61,
#         "chunk_length": 10.56000000000006,
#         "text": " did was, hey, there are these open source large language models that exist, right? I mean,",
#         "start_time": 367.84,
#         "end_time": 373.12
#     },
#     {
#         "chunk_id": 62,
#         "chunk_length": 10.079999999999927,
#         "text": " everybody knows about the Lama family from Meta. They also know there are others like Mr.",
#         "start_time": 373.12,
#         "end_time": 378.15999999999997
#     },
#     {
#         "chunk_id": 63,
#         "chunk_length": 12.479999999999905,
#         "text": " Al, there are a bunch of open source, you know, large language models. And then we said,",
#         "start_time": 378.32000000000005,
#         "end_time": 384.56
#     },
#     {
#         "chunk_id": 64,
#         "chunk_length": 10.880000000000052,
#         "text": " is there any way that take an existing open source model and teach it language skills, right?  I mean, you know, language and that is really the, you know, what we decide, what we said that",
#         "start_time": 384.56,
#         "end_time": 395.44000000000005
#     },
#     {
#         "chunk_id": 65,
#         "chunk_length": 11.839999999999918,
#         "text": " can we do something like that? And is this a, you know, relatively frugal way of actually,",
#         "start_time": 395.44000000000005,
#         "end_time": 401.36
#     },
#     {
#         "chunk_id": 66,
#         "chunk_length": 12.560000000000002,
#         "text": " you know, making models, you know, work in diverse languages because the truth is still today.  I mean, if you look at the amount of data and knowledge, it is still English dominates these",
#         "start_time": 402.0,
#         "end_time": 414.56
#     },
#     {
#         "chunk_id": 67,
#         "chunk_length": 10.399999999999977,
#         "text": " things. And I think that how do you actually take and make it understand Indian language,",
#         "start_time": 414.56,
#         "end_time": 419.76
#     },
#     {
#         "chunk_id": 68,
#         "chunk_length": 11.360000000000014,
#         "text": " understand Indian context and all of those things in actually a, in an efficient way? And therefore,",
#         "start_time": 419.76,
#         "end_time": 425.44
#     },
#     {
#         "chunk_id": 69,
#         "chunk_length": 12.799999999999955,
#         "text": " this was an attempt through that. And it's an open hearty is, you know, is currently based on",
#         "start_time": 425.44,
#         "end_time": 431.84
#     },
#     {
#         "chunk_id": 70,
#         "chunk_length": 11.28000000000003,
#         "text": " the Lama 7 billion model, but we'll be releasing many more models in different languages,  different sizes and things like that as part of this, as part of this series.",
#         "start_time": 431.84,
#         "end_time": 443.12
#     },
#     {
#         "chunk_id": 71,
#         "chunk_length": 11.360000000000014,
#         "text": "And of course,  you know, we will be building further models on those and doing other things to actually,",
#         "start_time": 436.64,
#         "end_time": 448.0
#     },
#     {
#         "chunk_id": 72,
#         "chunk_length": 13.839999999999975,
#         "text": " and we'll also have end points that people can use. So therefore, it's not, it's definitely,  you know, something that people can can can use to things.",
#         "start_time": 448.0,
#         "end_time": 458.08
#     },
#     {
#         "chunk_id": 73,
#         "chunk_length": 10.879999999999995,
#         "text": "And the, that's, that's the essence of,  of what, what this open hearty is.",
#         "start_time": 451.76,
#         "end_time": 462.64
#     },
#     {
#         "chunk_id": 74,
#         "chunk_length": 11.360000000000014,
#         "text": "So what does it mean to people in the audience here who are either  doing their own startups or a business or, or, or developers?",
#         "start_time": 458.08,
#         "end_time": 469.44
#     },
#     {
#         "chunk_id": 75,
#         "chunk_length": 13.519999999999982,
#         "text": "How should they look at Open AI?  Oh, sorry, sorry, not open.",
#         "start_time": 462.64,
#         "end_time": 476.15999999999997
#     },
#     {
#         "chunk_id": 76,
#         "chunk_length": 12.39999999999992,
#         "text": "No, yeah, no, no, I think, I think the way you look at it is that we,  one of the important things that we are doing is we're not just building models.",
#         "start_time": 469.44,
#         "end_time": 482.0
#     },
#     {
#         "chunk_id": 77,
#         "chunk_length": 12.799999999999955,
#         "text": "We are also going  to be building a platform, a platform for developers where you can actually use a combination of",
#         "start_time": 476.32000000000005,
#         "end_time": 489.12
#     },
#     {
#         "chunk_id": 78,
#         "chunk_length": 8.720000000000027,
#         "text": " various different kinds of models, some which are from us, some which are open source, some  which may not be open source, and actually to actually pull together and figure out how to",
#         "start_time": 489.12,
#         "end_time": 497.84000000000003
#     },
#     {
#         "chunk_id": 79,
#         "chunk_length": 11.919999999999959,
#         "text": " deploy, you know, generative AI applications at scale and understand and evaluate their performance  in an efficient manner.",
#         "start_time": 497.84000000000003,
#         "end_time": 509.76
#     },
#     {
#         "chunk_id": 80,
#         "chunk_length": 14.32000000000005,
#         "text": "And that's something that we are planning to do at this, and, and, and this  platform is, you know, in the next couple of months, we'll be coming out there, it will be available  to developers.",
#         "start_time": 505.36,
#         "end_time": 519.6800000000001
#     },
#     {
#         "chunk_id": 81,
#         "chunk_length": 10.960000000000036,
#         "text": "But of course, those who want to start with the open source things and, and hack,  but that of course, please go ahead and do that as well.",
#         "start_time": 514.64,
#         "end_time": 525.6
#     },
#     {
#         "chunk_id": 82,
#         "chunk_length": 11.839999999999918,
#         "text": "That's, that's phenomenal. But how does it",
#         "start_time": 519.6800000000001,
#         "end_time": 525.6
#     },
#     {
#         "chunk_id": 83,
#         "chunk_length": 7.67999999999995,
#         "text": " compare to Open AI itself or Google?",
#         "start_time": 525.6,
#         "end_time": 533.28
#     },
#     {
#         "chunk_id": 84,
#         "chunk_length": 7.67999999999995,
#         "text": "See, at least the things that we are doing now, right?",
#         "start_time": 525.6,
#         "end_time": 533.28
#     },
#     {
#         "chunk_id": 85,
#         "chunk_length": 13.039999999999964,
#         "text": "I mean,  one of the things that when we thought about a building server, we said we want to build a",
#         "start_time": 525.6,
#         "end_time": 538.64
#     },
#     {
#         "chunk_id": 86,
#         "chunk_length": 11.039999999999964,
#         "text": " full stack generative AI company and, and different people have, and, and our understanding of  full stack is that we need to know how to train models from scratch.",
#         "start_time": 539.52,
#         "end_time": 550.56
#     },
#     {
#         "chunk_id": 87,
#         "chunk_length": 12.400000000000091,
#         "text": "We need to know how to kind of  figure out how to deploy models to solve real world use cases.",
#         "start_time": 544.0799999999999,
#         "end_time": 556.48
#     },
#     {
#         "chunk_id": 88,
#         "chunk_length": 12.399999999999977,
#         "text": "And we need to play in the ecosystem  to make sure that we can actually deploy population scale applications, right?",
#         "start_time": 550.56,
#         "end_time": 562.9599999999999
#     },
#     {
#         "chunk_id": 89,
#         "chunk_length": 11.519999999999868,
#         "text": "So we were  thinking about all of these things.",
#         "start_time": 556.48,
#         "end_time": 568.0
#     },
#     {
#         "chunk_id": 90,
#         "chunk_length": 10.480000000000018,
#         "text": "But still the models we were talking about are, you know,  fairly small models.",
#         "start_time": 562.96,
#         "end_time": 573.44
#     },
#     {
#         "chunk_id": 91,
#         "chunk_length": 10.88000000000011,
#         "text": "They are fairly small models, right? The seven to maybe up to 70 billion kind",
#         "start_time": 568.0,
#         "end_time": 573.44
#     },
#     {
#         "chunk_id": 92,
#         "chunk_length": 10.079999999999927,
#         "text": " of range we're talking about. While these models like Open AI and, and, and Google are obviously",
#         "start_time": 573.44,
#         "end_time": 578.48
#     },
#     {
#         "chunk_id": 93,
#         "chunk_length": 10.400000000000091,
#         "text": " much bigger models, right? But we want to, but, but, you know, we want to understand the techniques and",
#         "start_time": 578.48,
#         "end_time": 583.6800000000001
#     },
#     {
#         "chunk_id": 94,
#         "chunk_length": 11.919999999999959,
#         "text": " be able to build that muscle to do all of these things to, to, to make it, to make it available to  people.",
#         "start_time": 583.6800000000001,
#         "end_time": 595.5999999999999
#     },
#     {
#         "chunk_id": 95,
#         "chunk_length": 12.240000000000009,
#         "text": "Now those models are, I mean, as I said, you know, I think that there is space for all of  those things.",
#         "start_time": 589.68,
#         "end_time": 601.92
#     },
#     {
#         "chunk_id": 96,
#         "chunk_length": 14.400000000000091,
#         "text": "And I think as even Sridhar was talking about earlier in the day, we believe that  these smaller models can do very, I mean, many, many kind of domain specific tasks extremely well,",
#         "start_time": 595.5999999999999,
#         "end_time": 610.0
#     },
#     {
#         "chunk_id": 97,
#         "chunk_length": 13.759999999999877,
#         "text": " probably even better than the, than the larger models. And that is really one of the key areas.  And, and so the further value of these kinds of things, right?",
#         "start_time": 610.0,
#         "end_time": 619.4399999999999
#     },
#     {
#         "chunk_id": 98,
#         "chunk_length": 9.919999999999959,
#         "text": "We are not aiming in these  most set of models to, to build any AGI, right?",
#         "start_time": 614.96,
#         "end_time": 624.88
#     },
#     {
#         "chunk_id": 99,
#         "chunk_length": 10.88000000000011,
#         "text": "That's not our goal here. Our goal is to make things",
#         "start_time": 619.4399999999999,
#         "end_time": 624.88
#     },
#     {
#         "chunk_id": 100,
#         "chunk_length": 14.879999999999995,
#         "text": " that work extremely well for domain specific use cases or, or increase accessibility through language  and, and all of those kinds of things. And obviously all of this unique to India.",
#         "start_time": 624.88,
#         "end_time": 635.76
#     },
#     {
#         "chunk_id": 101,
#         "chunk_length": 11.519999999999982,
#         "text": "But what is unique  about India?",
#         "start_time": 631.76,
#         "end_time": 643.28
#     },
#     {
#         "chunk_id": 102,
#         "chunk_length": 11.199999999999932,
#         "text": "I mean, like, what is, is anything special in our ecosystem that, that makes small models  focused with Indian languages better for, more suited for our problems.",
#         "start_time": 635.76,
#         "end_time": 646.9599999999999
#     },
#     {
#         "chunk_id": 103,
#         "chunk_length": 10.480000000000132,
#         "text": " So I think that, I mean, there are quite a few things that are unique about India, right?  The first thing is, I think, that we are a voice first nation.",
#         "start_time": 647.92,
#         "end_time": 659.12
#     },
#     {
#         "chunk_id": 104,
#         "chunk_length": 12.32000000000005,
#         "text": "So therefore, I think voice  has to be the core to doing things.",
#         "start_time": 653.8399999999999,
#         "end_time": 666.16
#     },
#     {
#         "chunk_id": 105,
#         "chunk_length": 11.67999999999995,
#         "text": "The other thing, of course, India is extremely,  it's a cost-conscious country from, from, from a cost perspective.",
#         "start_time": 659.12,
#         "end_time": 670.8
#     },
#     {
#         "chunk_id": 106,
#         "chunk_length": 14.159999999999968,
#         "text": "Now there, I would say that  there are lots of interesting use cases where you can use OpenAI and the cost structure works  that when, when, when, when, when depending on your application.",
#         "start_time": 666.16,
#         "end_time": 680.3199999999999
#     },
#     {
#         "chunk_id": 107,
#         "chunk_length": 13.67999999999995,
#         "text": "But when you want to scale things  to a massive level and make it work, then, then you have to figure out how small models work. So",
#         "start_time": 676.4,
#         "end_time": 685.1999999999999
#     },
#     {
#         "chunk_id": 108,
#         "chunk_length": 10.080000000000155,
#         "text": " that's something that is also specific to India. The third thing which is specific to India is",
#         "start_time": 685.1999999999999,
#         "end_time": 690.24
#     },
#     {
#         "chunk_id": 109,
#         "chunk_length": 12.319999999999936,
#         "text": " really the success that India has had in building all this digital public infrastructure. When you",
#         "start_time": 690.24,
#         "end_time": 696.4
#     },
#     {
#         "chunk_id": 110,
#         "chunk_length": 12.399999999999977,
#         "text": " add the AI layer on top of it, then you can actually get dramatic, you know, dramatic, I think,  multiplicative combinatorial effects based on doing things like that.",
#         "start_time": 696.4,
#         "end_time": 708.8
#     },
#     {
#         "chunk_id": 111,
#         "chunk_length": 14.6400000000001,
#         "text": "That's a phenomenal point.  Like, you know, it's like DPI to the power of AI almost in some ways. And as a part of Adar,",
#         "start_time": 703.28,
#         "end_time": 713.36
#     },
#     {
#         "chunk_id": 112,
#         "chunk_length": 12.960000000000036,
#         "text": " a building, Adar, no better person than you. So in summary, what I'm hearing is small models,",
#         "start_time": 713.36,
#         "end_time": 719.84
#     },
#     {
#         "chunk_id": 113,
#         "chunk_length": 10.480000000000018,
#         "text": " specialized with trained with Indic specific language data, suited for Indian problems,  at a compelling cost point, will be suited for us.",
#         "start_time": 720.56,
#         "end_time": 731.04
#     },
#     {
#         "chunk_id": 114,
#         "chunk_length": 10.240000000000009,
#         "text": "We're not solving some world autonomous  vehicles or some complex problem.",
#         "start_time": 725.92,
#         "end_time": 736.16
#     },
#     {
#         "chunk_id": 115,
#         "chunk_length": 10.240000000000009,
#         "text": "We're solving some basic problems specifically focused on  voice with multiple languages.",
#         "start_time": 731.04,
#         "end_time": 741.28
#     },
#     {
#         "chunk_id": 116,
#         "chunk_length": 10.240000000000009,
#         "text": "That is what you see as a future. Am I paraphrasing this correctly?",
#         "start_time": 736.16,
#         "end_time": 741.28
#     },
#     {
#         "chunk_id": 117,
#         "chunk_length": 10.720000000000027,
#         "text": " No, yeah. So I think that certainly, I mean, voice and Indian languages are an important part",
#         "start_time": 741.28,
#         "end_time": 746.64
#     },
#     {
#         "chunk_id": 118,
#         "chunk_length": 10.079999999999927,
#         "text": " of our strategy. But we will be building, you know, custom models to solve various other kinds",
#         "start_time": 746.64,
#         "end_time": 751.68
#     },
#     {
#         "chunk_id": 119,
#         "chunk_length": 11.680000000000064,
#         "text": " of problems as well, right? That's not just limited to, I think, in different domains, working",
#         "start_time": 751.68,
#         "end_time": 757.52
#     },
#     {
#         "chunk_id": 120,
#         "chunk_length": 13.3599999999999,
#         "text": " in different domains, making building things based on unique data that enterprises have and things  like that. So that's something that we'll also look at.",
#         "start_time": 757.52,
#         "end_time": 766.9599999999999
#     },
#     {
#         "chunk_id": 121,
#         "chunk_length": 13.599999999999909,
#         "text": "Fair enough. So coming back to the  elephant in the room, no fun intended with OpenHathi, what about Bhabhi Shakirwal and Krutram?",
#         "start_time": 763.04,
#         "end_time": 773.76
#     },
#     {
#         "chunk_id": 122,
#         "chunk_length": 14.160000000000082,
#         "text": " What does your take on that? I think it's great. I think it's wonderful, right?",
#         "start_time": 774.4,
#         "end_time": 779.12
#     },
#     {
#         "chunk_id": 123,
#         "chunk_length": 10.879999999999995,
#         "text": "I mean, the fact that  the technology AI is so important that we need multiple people working on it.",
#         "start_time": 774.4,
#         "end_time": 786.24
#     },
#     {
#         "chunk_id": 124,
#         "chunk_length": 11.839999999999918,
# ...
#         "start_time": 1183.28,
#         "end_time": 1192.8000000000002
#     },
#     {
#         "chunk_id": 190,
#         "chunk_length": 12.480000000000018,
#         "text": " you know, it's a, it's a very big, very tall, you know, mountain to climb. And that's why I think",
#         "start_time": 1193.44,
#         "end_time": 1199.68
#     },
#     {
#         "chunk_id": 191,
#         "chunk_length": 11.11999999999989,
#         "text": " it's important for both people and entities to think about how they will, you know, they will  upgrade themselves or they will modify their business processes to, you know, to a certain.",
#         "start_time": 1199.68,
#         "end_time": 1210.8
#     },
#     {
#         "chunk_id": 192,
#         "chunk_length": 12.480000000000018,
#         "text": " That's a very nuanced answer. And everybody here who's running a business should really think  about it, because life will be the same.",
#         "start_time": 1210.8,
#         "end_time": 1219.28
#     },
#     {
#         "chunk_id": 193,
#         "chunk_length": 14.400000000000091,
#         "text": "And then suddenly, suddenly something will, you know,  then it will be a step change. We make a few more questions, but I'm sure the audience has a",
#         "start_time": 1214.8,
#         "end_time": 1224.24
#     },
#     {
#         "chunk_id": 194,
#         "chunk_length": 7.519999999999982,
#         "text": " lot of questions for you.",
#         "start_time": 1224.24,
#         "end_time": 1231.76
#     },
#     {
#         "chunk_id": 195,
#         "chunk_length": 7.519999999999982,
#         "text": "So how are we doing on time?",
#         "start_time": 1224.24,
#         "end_time": 1231.76
#     },
#     {
#         "chunk_id": 196,
#         "chunk_length": 7.519999999999982,
#         "text": "Okay.",
#         "start_time": 1224.24,
#         "end_time": 1231.76
#     },
#     {
#         "chunk_id": 197,
#         "chunk_length": 10.799999999999955,
#         "text": "So does, okay, a lot of questions,  so love to, is there a mic that we can pass along?",
#         "start_time": 1224.24,
#         "end_time": 1235.04
#     },
#     {
#         "chunk_id": 198,
#         "chunk_length": 14.239999999999782,
#         "text": " Thank you. My name is Karthik.",
#         "start_time": 1240.48,
#         "end_time": 1247.6
#     },
#     {
#         "chunk_id": 199,
#         "chunk_length": 14.239999999999782,
#         "text": "I work for IT Service Industry. So you're saying that you're",
#         "start_time": 1240.48,
#         "end_time": 1247.6
#     },
#     {
#         "chunk_id": 200,
#         "chunk_length": 8.960000000000036,
#         "text": " working on LLM, sorry, it's a fine tuned LLM on top of Lama.",
#         "start_time": 1247.6,
#         "end_time": 1256.56
#     },
#     {
#         "chunk_id": 201,
#         "chunk_length": 14.480000000000018,
#         "text": "My basic question, fundamental  question is we don't have a foundation model for India.",
#         "start_time": 1247.6,
#         "end_time": 1262.08
#     },
#     {
#         "chunk_id": 202,
#         "chunk_length": 12.480000000000018,
#         "text": "Most of the models are basically using  English or those kind of things.",
#         "start_time": 1256.56,
#         "end_time": 1269.6799999999998
#     },
#     {
#         "chunk_id": 203,
#         "chunk_length": 13.2800000000002,
#         "text": "For example, Andrew was talking about the tokenizers and things  like that.",
#         "start_time": 1262.7199999999998,
#         "end_time": 1276.0
#     },
#     {
#         "chunk_id": 204,
#         "chunk_length": 12.640000000000327,
#         "text": "So are you working on anything like that? Or you want to use mostly the existing models",
#         "start_time": 1269.6799999999998,
#         "end_time": 1276.0
#     },
#     {
#         "chunk_id": 205,
#         "chunk_length": 12.239999999999782,
#         "text": " and run on top of it? Are you going to ask a good question? You ask a cherry question for himself.",
#         "start_time": 1276.0,
#         "end_time": 1280.08
#     },
#     {
#         "chunk_id": 206,
#         "chunk_length": 11.279999999999973,
#         "text": " No, I think the interesting thing is that if you look at, and then we have actually a blog  on this on our website, I think one of the things that we've actually built a customised tokenizer,",
#         "start_time": 1281.2,
#         "end_time": 1292.48
#     },
#     {
#         "chunk_id": 207,
#         "chunk_length": 11.920000000000073,
#         "text": " which actually fundamentally changes the cost of some of these generations in Indian languages.  And I think that we're not just fine tuning.",
#         "start_time": 1292.48,
#         "end_time": 1304.4
#     },
#     {
#         "chunk_id": 208,
#         "chunk_length": 10.320000000000164,
#         "text": "We're actually, we are leveraging the existing  retaining, but we are doing what's known as continual free training, which actually, but having",
#         "start_time": 1298.48,
#         "end_time": 1308.8000000000002
#     },
#     {
#         "chunk_id": 209,
#         "chunk_length": 12.159999999999854,
#         "text": " said that, you know, I think that when we have to figure out where is the data to train an extremely  large model from scratch and some of those things are things which will happen over time.",
#         "start_time": 1308.8000000000002,
#         "end_time": 1320.96
#     },
#     {
#         "chunk_id": 210,
#         "chunk_length": 13.039999999999964,
#         "text": "But I think  that, yes, I think that we will be doing various kinds of things.",
#         "start_time": 1315.3600000000001,
#         "end_time": 1328.4
#     },
#     {
#         "chunk_id": 211,
#         "chunk_length": 12.800000000000182,
#         "text": "But the interesting thing is that  if I want to change the accessibility problem with an existing open source model, how do I do that?",
#         "start_time": 1320.96,
#         "end_time": 1334.3200000000002
#     },
#     {
#         "chunk_id": 212,
#         "chunk_length": 12.400000000000318,
#         "text": " And that's the problem that we have that we think we have solved and is going to be the heart of this  open-art DCT. It's extremely well explained in the blog even I could understand it.",
#         "start_time": 1334.4,
#         "end_time": 1343.2800000000002
#     },
#     {
#         "chunk_id": 213,
#         "chunk_length": 8.47999999999979,
#         "text": " Hi, I'm Prishant.",
#         "start_time": 1343.2800000000002,
#         "end_time": 1351.76
#     },
#     {
#         "chunk_id": 214,
#         "chunk_length": 8.47999999999979,
#         "text": "I work for a fit tech company.",
#         "start_time": 1343.2800000000002,
#         "end_time": 1351.76
#     },
#     {
#         "chunk_id": 215,
#         "chunk_length": 8.47999999999979,
#         "text": "My question is like, unlike China, we never had a",
#         "start_time": 1343.2800000000002,
#         "end_time": 1351.76
#     },
#     {
#         "chunk_id": 216,
#         "chunk_length": 6.880000000000109,
#         "text": " consumer facing application coming out from India and in web one, web two, crypto and all.",
#         "start_time": 1351.76,
#         "end_time": 1358.64
#     },
#     {
#         "chunk_id": 217,
#         "chunk_length": 9.200000000000045,
#         "text": " Why do you think it will be different this time in like AI?",
#         "start_time": 1359.3600000000001,
#         "end_time": 1368.5600000000002
#     },
#     {
#         "chunk_id": 218,
#         "chunk_length": 9.200000000000045,
#         "text": "Because will the BPI and other things",
#         "start_time": 1359.3600000000001,
#         "end_time": 1368.5600000000002
#     },
#     {
#         "chunk_id": 219,
#         "chunk_length": 12.960000000000036,
#         "text": " will solve the same purpose, but the great five world did in China? Or do you think like in",
#         "start_time": 1368.5600000000002,
#         "end_time": 1375.0400000000002
#     },
#     {
#         "chunk_id": 220,
#         "chunk_length": 8.319999999999936,
#         "text": " NASA?",
#         "start_time": 1375.0400000000002,
#         "end_time": 1383.3600000000001
#     },
#     {
#         "chunk_id": 221,
#         "chunk_length": 13.3599999999999,
#         "text": "Because AI is a strategic sector, no outside country can work in NASA projects, maybe  or government content will go to them.",
#         "start_time": 1375.0400000000002,
#         "end_time": 1388.4799999999998
#     },
#     {
#         "chunk_id": 222,
#         "chunk_length": 13.680000000000064,
#         "text": "What is at least the mode here for an Indian company?  So I think the question is, I don't know the answer to these questions, right?",
#         "start_time": 1383.4399999999998,
#         "end_time": 1399.76
#     },
#     {
#         "chunk_id": 223,
#         "chunk_length": 8.6400000000001,
#         "text": "I mean, I think that",
#         "start_time": 1391.12,
#         "end_time": 1399.76
#     },
#     {
#         "chunk_id": 224,
#         "chunk_length": 13.120000000000346,
#         "text": " it's difficult to predict. But I do believe, and as I'm repeating, that the combinatorial effect of",
#         "start_time": 1400.4799999999998,
#         "end_time": 1407.04
#     },
#     {
#         "chunk_id": 225,
#         "chunk_length": 13.039999999999964,
#         "text": " being using Gen AI at a large scale in addition, along with the DPI work that we've done in  India, will have people.",
#         "start_time": 1407.6799999999998,
#         "end_time": 1420.7199999999998
#     },
#     {
#         "chunk_id": 226,
#         "chunk_length": 12.0,
#         "text": "And I think that in the end, the intent is that people need to be able  to use it, and they will vote by things that are useful for them.",
#         "start_time": 1413.12,
#         "end_time": 1425.12
#     },
#     {
#         "chunk_id": 227,
#         "chunk_length": 11.120000000000118,
#         "text": "And if that doesn't happen,  you're right.",
#         "start_time": 1420.7199999999998,
#         "end_time": 1432.3999999999999
#     },
#     {
#         "chunk_id": 228,
#         "chunk_length": 11.200000000000045,
#         "text": "And I think that we have to figure out what is the mechanism of delivery of apps,  right?",
#         "start_time": 1425.6799999999998,
#         "end_time": 1436.8799999999999
#     },
#     {
#         "chunk_id": 229,
#         "chunk_length": 12.160000000000082,
#         "text": "And in how, where do Indians consume content? That's a question.  I'm so sorry, but we are out of time.",
#         "start_time": 1432.3999999999999,
#         "end_time": 1440.5600000000002
#     },
#     {
#         "chunk_id": 230,
#         "chunk_length": 13.759999999999991,
#         "text": "Vivek will be outside.  Yeah. So he would be able to answer the question. We have time for one last question.",
#         "start_time": 1437.3600000000001,
#         "end_time": 1444.0800000000002
#     },
#     {
#         "chunk_id": 231,
#         "chunk_length": 11.83999999999969,
#         "text": " Can I just take one last? Yeah.",
#         "start_time": 1444.0800000000002,
#         "end_time": 1450.0
#     },
#     {
#         "chunk_id": 232,
#         "chunk_length": 11.83999999999969,
#         "text": "Thank you. Thank you.",
#         "start_time": 1444.0800000000002,
#         "end_time": 1450.0
#     },
#     {
#         "chunk_id": 233,
#         "chunk_length": 11.83999999999969,
#         "text": "I'm Manish Kudhari. I'm from ISBR",
#         "start_time": 1444.0800000000002,
#         "end_time": 1450.0
#     },
#     {
#         "chunk_id": 234,
#         "chunk_length": 12.480000000000246,
#         "text": " Business School. Good that I got a chance to ask you this question. During lunchtime,",
#         "start_time": 1450.0,
#         "end_time": 1454.16
#     },
#     {
#         "chunk_id": 235,
#         "chunk_length": 10.319999999999936,
#         "text": " there were a few of our educationists whom we were talking about, and there was one from school,  and we are from the MBA institutions.",
#         "start_time": 1454.16,
#         "end_time": 1464.48
#     },
#     {
#         "chunk_id": 236,
#         "chunk_length": 10.559999999999945,
#         "text": "We were thinking of these present generations. How do we",
#         "start_time": 1459.2,
#         "end_time": 1464.48
#     },
#     {
#         "chunk_id": 237,
#         "chunk_length": 13.599999999999909,
#         "text": " get them into what you are doing? There is one thing that they have been regularly, that the  concentrations that they're working on, but artificial intelligence and getting into this,",
#         "start_time": 1465.2,
#         "end_time": 1474.16
#     },
#     {
#         "chunk_id": 238,
#         "chunk_length": 9.519999999999982,
#         "text": " getting them into their academics and making them a part of it is very important,  including the trainers who train them, making them future-ready into what you are doing is amazing.",
#         "start_time": 1474.16,
#         "end_time": 1483.68
#     },
#     {
#         "chunk_id": 239,
#         "chunk_length": 10.639999999999873,
#         "text": " And the speed that which is growing, it is calling for a lot of training that needs to be done.  Can you from your angle through some light on how we could make them future-ready?",
#         "start_time": 1483.68,
#         "end_time": 1494.8799999999999
#     },
#     {
#         "chunk_id": 240,
#         "chunk_length": 14.800000000000182,
#         "text": " How these people who are management graduates and from schools who are coming out,  how do we get into this part of technology that you spoke about?  So this is really a challenge because I think everyone will need to understand at some level",
#         "start_time": 1494.8799999999999,
#         "end_time": 1511.04
#     },
#     {
#         "chunk_id": 241,
#         "chunk_length": 12.320000000000164,
#         "text": " what this technology does. And I think that we have to rethink how we get everyone into",
#         "start_time": 1511.6,
#         "end_time": 1517.76
#     },
#     {
#         "chunk_id": 242,
#         "chunk_length": 13.680000000000518,
#         "text": " this. And this kind of education has to be at many different levels. There are",
#         "start_time": 1517.84,
#         "end_time": 1522.4
#     },
#     {
#         "chunk_id": 243,
#         "chunk_length": 11.040000000000191,
#         "text": " from a core set of having people who are extremely good at some, and there you don't need as many,  but then there are basically vast numbers of people who can actually leverage these tools.",
#         "start_time": 1523.12,
#         "end_time": 1534.16
#     },
#     {
#         "chunk_id": 244,
#         "chunk_length": 12.559999999999945,
#         "text": " By the way, the most important thing about, and maybe that's part of what makes an LLM interesting,  is that how you use it, your mileage varies by that.",
#         "start_time": 1534.16,
#         "end_time": 1546.72
#     },
#     {
#         "chunk_id": 245,
#         "chunk_length": 12.080000000000155,
#         "text": "And to understand how to actually leverage  in an interesting way is something that we have to widely teach many, many people.",
#         "start_time": 1539.52,
#         "end_time": 1552.16
#     },
#     {
#         "chunk_id": 246,
#         "chunk_length": 14.080000000000155,
#         "text": " Because asking the things in the right way and having the right kind of applications  will make a huge difference to how people can leverage these tools.  Awesome.",
#         "start_time": 1553.52,
#         "end_time": 1567.6000000000001
#     },
#     {
#         "chunk_id": 247,
#         "chunk_length": 13.680000000000518,
#         "text": "Thank you. Thank you very much Vivek. Very good luck to Sarvam and good luck to India.",
#         "start_time": 1563.04,
#         "end_time": 1567.6000000000001
#     },
#     {
#         "chunk_id": 248,
#         "chunk_length": 8.7199999999998,
#         "text": " I think it's going to be a lot right when we show this. Thanks, Palai.  Thank you, Mr. Raghavan.",
#         "start_time": 1567.6000000000001,
#         "end_time": 1574.8
#     }
# ]

# %% [markdown]
# ## Task 2: Exploratory Data Analysis of New Testament Audio and Text
#
# **Problem Statement:**
#
# The objective of this task is to conduct a comprehensive exploratory data analysis (EDA) on the audio and text data of the 260 chapters of the New Testament in your mother tongue (excluding English). The data should be obtained through web scraping from [Faith Comes By Hearing](https://www.faithcomesbyhearing.com/).
#
# The workflow for this task should include:
# 1. **Web Scraping:** Systematically download the audio files and their corresponding textual content for each of the 260 chapters of the New Testament from the specified website.
# 2. **Data Preparation:** Organize the data by chapters, ensuring each audio file is matched with its corresponding text.
# 3. **Exploratory Data Analysis:** Analyze the data to uncover patterns, anomalies, or insights that could benefit applications such as Text to Speech (TTS) and Speech to Text (STT) technologies. Your analysis should explore various facets of the data, including audio quality, text clarity, and alignment between text and spoken content.
#
# **Judgement Criteria:**
#
# Your submission will be evaluated based on:
# - **Efficiency and Reliability of Web Scraping Techniques:** The methods and tools used for downloading the chapters efficiently and reliably.
# - **Data Analysis Methods:** The techniques and approaches used for analyzing the audio and text data.
# - **Quality of Data Analysis:** How effectively the analysis addresses potential applications for the Speech team, including TTS and STT technologies.
# - **Creativity in Analysis:** Innovative approaches in data handling and analysis, and the use of relevant metrics to assess data quality and applicability.
#
# **Submission Requirements:**
#
# Your submission should include the following components:
# - **Report on Key Performance Indicators (KPIs):** A concise report detailing the key findings from your analysis, focusing on aspects that are critical for improving TTS and STT applications.
# - **Methodological Explanation:** A thorough explanation of the methods used for both web scraping and the exploratory data analysis. This should include challenges faced and how they were overcome.
# - **Supporting Materials:** Include code snippets and visualizations that highlight significant insights from the data. These should be well-documented and easy to understand, demonstrating the logic behind your analytical decisions.
#
# The report should be structured to clearly present the methodology, findings, and implications of your analysis. It should be technical yet accessible, aimed at stakeholders who may have varying levels of familiarity with data analysis techniques.
#
#
# ---

# %%
# Your code for Task 2 goes here!
